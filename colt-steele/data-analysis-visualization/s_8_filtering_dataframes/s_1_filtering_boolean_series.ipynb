# %%
import pandas as pd
titanic=pd.read_csv("../data/titanic.csv")
df=titanic.head()

# %%
df.sex
# Out:
# 0    female
# 1      male
# 2    female
# 3      male
# 4    female
# Name: sex, dtype: object

# %%
df.sex=='female'
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: sex, dtype: bool

# %%
# get whole row
df[df.sex=='female']
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#   age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0  29      0      0   24160  211.3375       B5        S    2    ?
# 2   2      1      2  113781    151.55  C22 C26        S    ?    ?
# 4  25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# 2  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
df.survived==0
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: survived, dtype: bool

# %%
df[df.survived==0]
# Out:
#    pclass  survived                                             name     sex  \
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#   age  sibsp  parch  ticket    fare    cabin embarked boat body  \
# 2   2      1      2  113781  151.55  C22 C26        S    ?    ?
# 3  30      1      2  113781  151.55  C22 C26        S    ?  135
# 4  25      1      2  113781  151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# # Filtering With Comparison Operators

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %%
# age is object string so we use "" operator
titanic.age=="18"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1304    False
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# Name: age, Length: 1309, dtype: bool

# %%
titanic[titanic.age=="18"].head()
# Out:
#      pclass  survived                                               name  \
# 11        1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 198       1         1  Marvin, Mrs. Daniel Warner (Mary Graham Carmic...
# 228       1         0         Penasco y Castellana, Mr. Victor de Satode
# 250       1         1                         Ryerson, Miss. Emily Borie
# 270       1         1     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)
#
#         sex age  sibsp  parch    ticket     fare            cabin embarked  \
# 11   female  18      1      0  PC 17757  227.525          C62 C64        C
# 198  female  18      1      0    113773     53.1              D30        S
# 228    male  18      1      0  PC 17758    108.9              C65        C
# 250  female  18      2      2  PC 17608  262.375  B57 B59 B63 B66        C
# 270  female  18      1      0     13695       60              C31        S
#
#     boat body                        home.dest
# ...

# %%
# find all the rows in titanic where class is 2 or 3
titanic.pclass!=1
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1304     True
# 1305     True
# 1306     True
# 1307     True
# 1308     True
# Name: pclass, Length: 1309, dtype: bool

# %%
titanic[titanic.pclass!=1].pclass.value_counts()
# Out:
# 3    709
# 2    277
# Name: pclass, dtype: int64

# %%
titanic[titanic.pclass!=1].pclass.value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
# find houses greater than 5 million dollars
houses=pd.read_csv("../data/kc_house_data.csv")
houses.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
houses["price"]>5000000
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Name: price, Length: 21613, dtype: bool

# %%
houses[houses["price"]>5000000]
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1164         8010     45517     2.0           1     4  ...     12        5990
# 1315         7390     24829     2.0           1     4  ...     12        5000
# 1448         8000     23985     2.0           0     4  ...     12        6720
# 3914        10040     37325     2.0           1     2  ...     11        7680
# ...

# %%
# find the house between 5 to 7 bedrooms
houses["bedrooms"].between(5,7)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Name: bedrooms, Length: 21613, dtype: bool

# %%
houses[houses["bedrooms"].between(5,7)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 14     1175000570  20150312T000000   530000.0         5       2.00
# 22     7137970340  20140703T000000   285000.0         5       2.50
# 42     7203220400  20140707T000000   861990.0         5       2.75
# 51     7231300125  20150217T000000   345000.0         5       2.50
# 54     4217401195  20150303T000000   920000.0         5       2.25
# ...           ...              ...        ...       ...        ...
# 21564  7168100015  20141009T000000   579950.0         5       2.75
# 21576  9253900271  20150107T000000  3567000.0         5       4.50
# 21593  8672200110  20150317T000000  1088000.0         5       3.75
# 21596  7502800100  20140813T000000   679950.0         5       2.75
# 21600   249000205  20141015T000000  1537000.0         5       3.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 14            1810      4850     1.5           0     0  ...      7
# ...

# %%
houses[houses["bedrooms"].between(5,7)].bedrooms.value_counts()
# Out:
# 5    1601
# 6     272
# 7      38
# Name: bedrooms, dtype: int64

# %%
# find the grade of houses between 11 & 13

# %%
houses[houses["grade"].between(11,13)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 70     1525059190  20140912T000000  1040000.0         5       3.25
# 153    7855801670  20150401T000000  2250000.0         4       3.25
# 269    7960900060  20150504T000000  2900000.0         4       3.25
# 270    4054500390  20141007T000000  1365000.0         4       4.75
# ...           ...              ...        ...       ...        ...
# 21532   324069112  20140617T000000  1325000.0         4       4.00
# 21548  8835770330  20140819T000000  1057000.0         2       1.50
# 21551  1561750040  20141224T000000  1375000.0         5       4.50
# 21590  7430200100  20140514T000000  1222500.0         4       3.50
# 21600   249000205  20141015T000000  1537000.0         5       3.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 5             5420    101930     1.0           0     0  ...     11
# ...

# %%
houses[houses["grade"].between(11,13)].grade.value_counts()
# Out:
# 11    399
# 12     90
# 13     13
# Name: grade, dtype: int64

# %% [markdown]
# # isin() method

# %%
netflix=pd.read_csv("../data/netflix_titles.csv",sep="|",index_col=3)
netflix
# Out:
#                        Unnamed: 0 show_id     type         director  \
# title
# Dick Johnson Is Dead            0      s1    Movie  Kirsten Johnson
# Blood & Water                   1      s2  TV Show              NaN
# Ganglands                       2      s3  TV Show  Julien Leclercq
# Jailbirds New Orleans           3      s4  TV Show              NaN
# Kota Factory                    4      s5  TV Show              NaN
# ...                           ...     ...      ...              ...
# Zodiac                       8802   s8803    Movie    David Fincher
# Zombie Dumb                  8803   s8804  TV Show              NaN
# Zombieland                   8804   s8805    Movie  Ruben Fleischer
# Zoom                         8805   s8806    Movie     Peter Hewitt
# Zubaan                       8806   s8807    Movie      Mozez Singh
#
#                                                                     cast  \
# title
# ...

# %%
# find different show or movies in japan, south korea in india
countries=["India","Japan","South Korea"]
netflix["country"].isin(countries)
# Out:
# title
# Dick Johnson Is Dead     False
# Blood & Water            False
# Ganglands                False
# Jailbirds New Orleans    False
# Kota Factory              True
#                          ...
# Zodiac                   False
# Zombie Dumb              False
# Zombieland               False
# Zoom                     False
# Zubaan                    True
# Name: country, Length: 8807, dtype: bool

# %%
netflix[netflix["country"].isin(countries)]
# Out:
#                                                     Unnamed: 0 show_id  \
# title
# Kota Factory                                                 4      s5
# Jeans                                                       24     s25
# Chhota Bheem                                                39     s40
# Dharmakshetra                                               50     s51
# InuYasha the Movie 2: The Castle Beyond the Loo...          51     s52
# ...                                                        ...     ...
# Yanda Kartavya Aahe                                       8773   s8774
# Yeh Meri Family                                           8775   s8776
# Zed Plus                                                  8798   s8799
# Zenda                                                     8799   s8800
# Zubaan                                                    8806   s8807
#
#                                                        type  \
# title
# ...

# %%
netflix[netflix["country"].isin(countries)]['country'].value_counts()
# Out:
# India          972
# Japan          245
# South Korea    199
# Name: country, dtype: int64

# %%
# Find TVMA or R rated shows
mature=netflix["rating"].isin(["TV-MA","R"])

# %%
netflix[mature]
# Out:
#                        Unnamed: 0 show_id     type                 director  \
# title
# Blood & Water                   1      s2  TV Show                      NaN
# Ganglands                       2      s3  TV Show          Julien Leclercq
# Jailbirds New Orleans           3      s4  TV Show                      NaN
# Kota Factory                    4      s5  TV Show                      NaN
# Midnight Mass                   5      s6  TV Show            Mike Flanagan
# ...                           ...     ...      ...                      ...
# Young Adult                  8791   s8792    Movie            Jason Reitman
# Zed Plus                     8798   s8799    Movie  Chandra Prakash Dwivedi
# Zinzana                      8801   s8802    Movie          Majid Al Ansari
# Zodiac                       8802   s8803    Movie            David Fincher
# Zombieland                   8804   s8805    Movie          Ruben Fleischer
#
# ...
