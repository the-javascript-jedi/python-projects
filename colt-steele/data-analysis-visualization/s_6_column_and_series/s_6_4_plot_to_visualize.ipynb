# %%
import pandas as pd
houses=pd.read_csv("../data/kc_house_data.csv")
titanic=pd.read_csv("../data/titanic.csv")
netflix=pd.read_csv("../data/netflix_titles.csv",sep="|",index_col=0)

# %%
houses.bedrooms.value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
houses.bedrooms.value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
houses.bedrooms.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='bedrooms'>

# %%
titanic.survived.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='survived'>

# %%
titanic.sex.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='sex'>

# %% [markdown]
# # using plot() in a dataframe

# %%
df=houses[['bedrooms','bathrooms']]
df
# Out:
#        bedrooms  bathrooms
# 0             3       1.00
# 1             3       2.25
# 2             2       1.00
# 3             4       3.00
# 4             3       2.00
# ...         ...        ...
# 21608         3       2.50
# 21609         4       2.50
# 21610         2       0.75
# 21611         3       2.50
# 21612         2       0.75
#
# [21613 rows x 2 columns]

# %%
df=houses[['bedrooms','bathrooms']]
df.plot()
# Out:
# <Axes: >

# %%
# we can manually say whch plot point should be x or y in a dataframe
df.plot(kind="scatter",x="bedrooms",y="bathrooms")
# Out:
# <Axes: xlabel='bedrooms', ylabel='bathrooms'>

# %%
netflix.rating.value_counts()
# Out:
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: rating, dtype: int64

# %%
netflix.rating.value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: >
