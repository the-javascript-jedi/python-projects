# %%
import matplotlib.pyplot as plt
import numpy as np
nums=np.arange(5)
plt.plot(nums,nums)

# %%
# custom title
salaries=[55000,65000,72000,90000,115000,150000]
ages=[20,25,30,32,40,45]
plt.plot(ages,salaries)
plt.title("Company Salaries")
# create a new figure and provide a distinct title
plt.figure()
plt.plot(nums,nums,color="olive",linewidth=4,linestyle="dashed")
# move title to right side
plt.title("Linear Stuff",loc="right")
# Out:
# Text(1.0, 1.0, 'Linear Stuff')

# %%
# change label of x axis
salaries=[55000,65000,72000,90000,115000,150000]
ages=[20,25,30,32,40,45]
plt.plot(ages,salaries)
plt.title("Company Salaries",color="green")
# labelpad - provides label spacing
plt.xlabel("Age",labelpad=10)
plt.ylabel("Average Salary",labelpad=10,fontsize=24,rotation="vertical")
# Out:
# Text(0, 0.5, 'Average Salary')

# %% [markdown]
# # Changing X & Y Ticks

# %%
# change label of x axis
salaries=[55000,65000,72000,90000,115000,150000]
ages=[20,25,30,32,40,45]
plt.plot(ages,salaries)
plt.title("Company Salaries",color="green")
# manual ticks
plt.xticks([20,25,30,35,40,45])
plt.yticks([60000,80000,100000,120000,140000],labels=["60k","60k","60k","60k","60k"]
# Out:
# ([<matplotlib.axis.YTick at 0x200aaa46a70>,
#   <matplotlib.axis.YTick at 0x200aaa47f40>,
#   <matplotlib.axis.YTick at 0x200aaa47010>,
#   <matplotlib.axis.YTick at 0x200ae6373d0>,
#   <matplotlib.axis.YTick at 0x200ae637e80>],
#  [Text(0, 60000, '60000'),
#   Text(0, 80000, '80000'),
#   Text(0, 100000, '100000'),
#   Text(0, 120000, '120000'),
#   Text(0, 140000, '140000')])
